# %% [markdown]
# ## Funciones

# %% [markdown]
# ## Librerías

# %% [markdown]
# Objetivo: Obtener los parámetros HH al darle al programa parámetros GQH

# %%
# Out:
# |   iter    |  target   |     s     |     d     |    mu     |     a     |
# -------------------------------------------------------------------------
# | 1         | -0.000624 | 0.9988962 | 2.8570714 | 73199.662 | 2.4347680 |
# | 2         | -0.023555 | 0.4744447 | 0.5523841 | 5809.3031 | 3.4780869 |
# | 3         | -0.020655 | 1.5426760 | 2.1534104 | 2059.4288 | 3.8826484 |
# | 4         | -0.004841 | 2.0978623 | 0.7157834 | 18183.314 | 0.8152775 |
# | 5         | -0.000572 | 0.8301813 | 1.6217936 | 43195.069 | 1.2357936 |
# | 6         | -0.001998 | 1.5684469 | 0.5045321 | 29215.172 | 1.5288111 |
# | 7         | -0.000322 | 1.1945679 | 2.3770102 | 19968.178 | 2.1055143 |
# | 8         | -0.001840 | 1.5217949 | 0.2347061 | 60754.877 | 0.7650440 |
# | 9         | -0.012744 | 1.6492824 | 2.4501656 | 87035.529 | 3.5398069 |
# | 10        | -0.019838 | 0.3913222 | 1.2553116 | 19722.463 | 3.0999958 |
# | 11        | -0.000443 | 0.8670446 | 1.0665008 | 43196.196 | 1.8153388 |
# ...
