# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(),"..")))

import numpy as np
from modules.seismo_response.class_frequency_spectrum import (
                                                                Frequency_Spectrum,  
                                                            )

# %% [markdown]
# - ¿Para que sirve esta clase?
# - Genera objetos que guardan espectros de frecuencia.
# - ¿Qué necesito para usarla?

# %%
data = np.array([
    [0.1, 0.02],
    [0.2, 0.05],
    [0.5, 0.12],
    [1.0, 0.25],
    [2.0, 0.40],
    [3.0, 0.35],
    [5.0, 0.20],
    [7.0, 0.10],
    [10.0, 0.05],
    [15.0, 0.02]
])

# %%
spectrum = Frequency_Spectrum(data=data)

# %%
spectrum.plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Frequency [Hz]', ylabel='Amplitude or phase'>)

# %%
spectrum.get_smoothed(win_len=9, show_fig=True,log_scale=True)
# Out:
# (array([0.11      , 0.104     , 0.1056    , 0.12004   , 0.27352476,
#         0.26550699, 0.1004825 , 0.089425  , 0.08825   , 0.0925    ]),
#  <Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='Frequency [Hz]', ylabel='Spectrum'>)
